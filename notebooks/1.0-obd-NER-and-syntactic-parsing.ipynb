# %%
from deeppavlov import build_model, configs
model = build_model(configs.syntax.syntax_ru_syntagrus_bert, download=True)
sentences = ["Я шёл домой по незнакомой улице.", "Девушка пела в церковном хоре."]
for parse in model(sentences):
    print(parse, end="\n\n")
# Out:
# 2021-12-16 05:21:55.821 INFO in 'deeppavlov.core.data.utils'['utils'] at line 94: Downloading from http://files.deeppavlov.ai/deeppavlov_data/syntax_parser/syntax_ru_syntagrus_bert.tar.gz to C:\Users\Oleg\.deeppavlov\models\syntax_ru_syntagrus_bert.tar.gz
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     658             timeout_obj = self._get_timeout(timeout)
# --> 659             conn = self._get_conn(timeout=pool_timeout)
#     660
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\urllib3\connectionpool.py in _get_conn(self, timeout)
#     278
# --> 279         return conn or self._new_conn()
#     280
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\urllib3\connectionpool.py in _new_conn(self)
#     946         if not self.ConnectionCls or self.ConnectionCls is DummyConnection:
# --> 947             raise SSLError(
#     948                 "Can't connect to HTTPS URL because the SSL module is not available."
#
# SSLError: Can't connect to HTTPS URL because the SSL module is not available.
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='files.deeppavlov.ai', port=443): Max retries exceeded with url: /deeppavlov_data/syntax_parser/syntax_ru_syntagrus_bert.tar.gz (Caused by SSLError("Can't connect to HTTPS URL because the SSL module is not available."))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_672/1778635312.py in <module>
#       1 from deeppavlov import build_model, configs
# ----> 2 model = build_model(configs.syntax.syntax_ru_syntagrus_bert, download=True)
#       3 sentences = ["Я шёл домой по незнакомой улице.", "Девушка пела в церковном хоре."]
#       4 for parse in model(sentences):
#       5     print(parse, end="\n\n")
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\deeppavlov\core\commands\infer.py in build_model(config, mode, load_trained, download, serialized)
#      39
#      40     if download:
# ---> 41         deep_download(config)
#      42
#      43     import_packages(config.get('metadata', {}).get('imports', []))
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\deeppavlov\download.py in deep_download(config)
#     164         if not url.startswith('s3://') and not isinstance(config, dict):
#     165             url = set_query_parameter(url, 'config', Path(config).stem)
# --> 166         download_resource(url, dest_paths)
#     167
#     168
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\deeppavlov\download.py in download_resource(url, dest_paths)
#     138             log.info(f'Skipped {url} download because of matching hashes')
#     139         elif any(ext in url for ext in ('.tar.gz', '.gz', '.zip')):
# --> 140             download_decompress(url, download_path, dest_paths)
#     141         else:
#     142             dest_files = [dest_path / file_name for dest_path in dest_paths]
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\deeppavlov\core\data\utils.py in download_decompress(url, download_path, extract_paths)
#     262     else:
#     263         arch_file_path = download_path / file_name
# --> 264         simple_download(url, arch_file_path)
#     265         extracted_path = extract_paths.pop()
#     266
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\deeppavlov\core\data\utils.py in simple_download(url, destination)
#     101
#     102     headers = {'dp-token': _get_download_token()}
# --> 103     r = requests.get(url, stream=True, headers=headers)
#     104     if r.status_code != 200:
#     105         raise RuntimeError(f'Got status code {r.status_code} when trying to download {url}')
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     237             else:
#     238
# --> 239                 resp = self.send(
#     240                     req,
#     241                     stream=stream,
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\Users\Oleg\Documents\Pyth\env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='files.deeppavlov.ai', port=443): Max retries exceeded with url: /deeppavlov_data/syntax_parser/syntax_ru_syntagrus_bert.tar.gz (Caused by SSLError("Can't connect to HTTPS URL because the SSL module is not available."))
